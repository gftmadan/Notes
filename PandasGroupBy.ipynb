# %%
import pandas as pd
import numpy as np

# %%
dfmv = pd.read_csv(r"D:\Notes_Notebooks\Data\imdb-top-1000.csv")
dfmtch = pd.read_csv(r"D:\Notes_Notebooks\Data\deliveries.csv")

# %%
dfmv
# Out:
#                  Series_Title Released_Year  Runtime   Genre  IMDB_Rating  \
# 0    The Shawshank Redemption          1994      142   Drama          9.3
# 1               The Godfather          1972      175   Crime          9.2
# 2             The Dark Knight          2008      152  Action          9.0
# 3      The Godfather: Part II          1974      202   Crime          9.0
# 4                12 Angry Men          1957       96   Crime          9.0
# ..                        ...           ...      ...     ...          ...
# 995    Breakfast at Tiffany's          1961      115  Comedy          7.6
# 996                     Giant          1956      201   Drama          7.6
# 997     From Here to Eternity          1953      118   Drama          7.6
# 998                  Lifeboat          1944       97   Drama          7.6
# 999              The 39 Steps          1935       86   Crime          7.6
#
#                  Director              Star1  No_of_Votes        Gross  \
# ...

# %%
dfmtch
# Out:
#         match_id  inning         batting_team                 bowling_team  \
# 0              1       1  Sunrisers Hyderabad  Royal Challengers Bangalore
# 1              1       1  Sunrisers Hyderabad  Royal Challengers Bangalore
# 2              1       1  Sunrisers Hyderabad  Royal Challengers Bangalore
# 3              1       1  Sunrisers Hyderabad  Royal Challengers Bangalore
# 4              1       1  Sunrisers Hyderabad  Royal Challengers Bangalore
# ...          ...     ...                  ...                          ...
# 179073     11415       2  Chennai Super Kings               Mumbai Indians
# 179074     11415       2  Chennai Super Kings               Mumbai Indians
# 179075     11415       2  Chennai Super Kings               Mumbai Indians
# 179076     11415       2  Chennai Super Kings               Mumbai Indians
# 179077     11415       2  Chennai Super Kings               Mumbai Indians
#
# ...

# %%
gnr = dfmv.groupby("Genre")
gnr

# %%
gnr.groups
# Out:
# {'Action': [2, 5, 8, 10, 13, 14, 16, 29, 30, 31, 39, 42, 44, 55, 57, 59, 60, 63, 68, 72, 106, 109, 129, 130, 134, 140, 142, 144, 152, 155, 160, 161, 166, 168, 171, 172, 177, 181, 194, 201, 202, 216, 217, 223, 224, 236, 241, 262, 275, 294, 308, 320, 325, 326, 331, 337, 339, 340, 343, 345, 348, 351, 353, 356, 357, 362, 368, 369, 375, 376, 390, 410, 431, 436, 473, 477, 479, 482, 488, 493, 496, 502, 507, 511, 532, 535, 540, 543, 564, 569, 570, 573, 577, 582, 583, 602, 605, 608, 615, 623, ...], 'Adventure': [21, 47, 93, 110, 114, 116, 118, 137, 178, 179, 191, 193, 209, 226, 231, 247, 267, 273, 281, 300, 301, 304, 306, 323, 329, 361, 366, 377, 402, 406, 415, 426, 458, 470, 497, 498, 506, 513, 514, 537, 549, 552, 553, 566, 576, 604, 609, 618, 638, 647, 675, 681, 686, 692, 711, 713, 739, 755, 781, 797, 798, 851, 873, 884, 912, 919, 947, 957, 964, 966, 984, 991], 'Animation': [23, 43, 46, 56, 58, 61, 66, 70, 101, 135, 146, 151, 158, 170, 197, 205, 211, 213, 219, 229, 230, 242, 245, 246, 270, 
# ...

# %%
gnr.indices
# Out:
# {'Action': array([  2,   5,   8,  10,  13,  14,  16,  29,  30,  31,  39,  42,  44,
#          55,  57,  59,  60,  63,  68,  72, 106, 109, 129, 130, 134, 140,
#         142, 144, 152, 155, 160, 161, 166, 168, 171, 172, 177, 181, 194,
#         201, 202, 216, 217, 223, 224, 236, 241, 262, 275, 294, 308, 320,
#         325, 326, 331, 337, 339, 340, 343, 345, 348, 351, 353, 356, 357,
#         362, 368, 369, 375, 376, 390, 410, 431, 436, 473, 477, 479, 482,
#         488, 493, 496, 502, 507, 511, 532, 535, 540, 543, 564, 569, 570,
#         573, 577, 582, 583, 602, 605, 608, 615, 623, 625, 627, 634, 641,
#         642, 645, 648, 655, 659, 663, 666, 674, 677, 678, 685, 696, 702,
#         705, 709, 710, 718, 722, 725, 730, 737, 746, 749, 751, 768, 774,
#         776, 777, 782, 784, 807, 821, 832, 839, 840, 847, 850, 852, 853,
#         854, 856, 861, 865, 887, 888, 889, 893, 896, 898, 900, 901, 908,
#         909, 914, 918, 924, 927, 928, 930, 931, 944, 951, 963, 968, 979,
# ...

# %%
gnr.get_group("Action")[100:150]
# Out:
#                             Series_Title Released_Year  Runtime   Genre  \
# 625                           Apocalypto          2006      139  Action
# 627                             Hot Fuzz          2007      121  Action
# 634                             Serenity          2005      119  Action
# 641         Gongdong gyeongbi guyeok JSA          2000      110  Action
# 642            The Count of Monte Cristo          2002      131  Action
# 645                      Wo hu cang long          2000      120  Action
# 648                  The Boondock Saints          1999      108  Action
# 655                             The Game          1997      129  Action
# 659                            Tombstone          1993      130  Action
# 663                         The Fugitive          1993      130  Action
# 666                     Lat sau san taam          1992      128  Action
# 674                  Dip huet seung hung          1989      111  Action
# ...

# %%
gnritr = gnr.__iter__()

# %%
gpnm,gpdf = next(gnritr)
gpdf
# Out:
#                                           Series_Title Released_Year  Runtime  \
# 2                                      The Dark Knight          2008      152
# 5        The Lord of the Rings: The Return of the King          2003      201
# 8                                            Inception          2010      148
# 10   The Lord of the Rings: The Fellowship of the Ring          2001      178
# 13               The Lord of the Rings: The Two Towers          2002      179
# ..                                                 ...           ...      ...
# 968                                       Falling Down          1993      113
# 979                                      Lethal Weapon          1987      109
# 982                                          Mad Max 2          1981       96
# 983                                       The Warriors          1979       92
# 985                               Escape from Alcatraz          1979      112
#
# ...

# %%
lst = []
for gpnm,gndf in gnr:
    lst.append(gndf)

a = lst[0]
a
# Out:
#                                           Series_Title Released_Year  Runtime  \
# 2                                      The Dark Knight          2008      152
# 5        The Lord of the Rings: The Return of the King          2003      201
# 8                                            Inception          2010      148
# 10   The Lord of the Rings: The Fellowship of the Ring          2001      178
# 13               The Lord of the Rings: The Two Towers          2002      179
# ..                                                 ...           ...      ...
# 968                                       Falling Down          1993      113
# 979                                      Lethal Weapon          1987      109
# 982                                          Mad Max 2          1981       96
# 983                                       The Warriors          1979       92
# 985                               Escape from Alcatraz          1979      112
#
# ...

# %%
type(lst[0])
# Out:
# pandas.core.frame.DataFrame

# %%
lst[1]
# Out:
#                        Series_Title Released_Year  Runtime      Genre  \
# 21                     Interstellar          2014      169  Adventure
# 47               Back to the Future          1985      116  Adventure
# 93             Inglourious Basterds          2009      153  Adventure
# 110                        Das Boot          1981      149  Adventure
# 114           2001: A Space Odyssey          1968      149  Adventure
# ..                              ...           ...      ...        ...
# 957  Fear and Loathing in Las Vegas          1998      118  Adventure
# 964                        Dead Man          1995      121  Adventure
# 966                       Apollo 13            PG      140  Adventure
# 984                The Muppet Movie          1979       95  Adventure
# 991                  Kelly's Heroes          1970      144  Adventure
#
#      IMDB_Rating           Director                Star1  No_of_Votes  \
# ...

# %%
lst[-1]
# Out:
#                         Series_Title Released_Year  Runtime    Genre  \
# 12   Il buono, il brutto, il cattivo          1966      161  Western
# 48      Once Upon a Time in the West          1968      165  Western
# 115       Per qualche dollaro in più          1965      132  Western
# 691           The Outlaw Josey Wales          1976      135  Western
#
#      IMDB_Rating        Director           Star1  No_of_Votes       Gross  \
# 12           8.8    Sergio Leone  Clint Eastwood       688390   6100000.0
# 48           8.5    Sergio Leone     Henry Fonda       302844   5321508.0
# 115          8.3    Sergio Leone  Clint Eastwood       232772  15000000.0
# 691          7.8  Clint Eastwood  Clint Eastwood        65659  31800000.0
#
#      Metascore
# 12        90.0
# 48        80.0
# 115       74.0
# 691       69.0

# %%
gnr_gross = gnr["Gross"]
gnr_gross

# %%
lst_srs = []
for gpnm,gpsr in gnr_gross:
    lst_srs.append(gpsr)
    
a = lst_srs[0]
a
# Out:
# 2      534858444.0
# 5      377845905.0
# 8      292576195.0
# 10     315544750.0
# 13     342551365.0
#           ...
# 968     40903593.0
# 979     65207127.0
# 982     12465371.0
# 983     22490039.0
# 985     43000000.0
# Name: Gross, Length: 172, dtype: float64

# %%
gnr_gross.sum()
# Out:
# Genre
# Action       3.263226e+10
# Adventure    9.496922e+09
# Animation    1.463147e+10
# Biography    8.276358e+09
# Comedy       1.566387e+10
# Crime        8.452632e+09
# Drama        3.540997e+10
# Family       4.391106e+08
# Fantasy      7.827267e+08
# Film-Noir    1.259105e+08
# Horror       1.034649e+09
# Mystery      1.256417e+09
# Thriller     1.755074e+07
# Western      5.822151e+07
# Name: Gross, dtype: float64

# %%
fg1 = gnr[["Gross","IMDB_Rating"]]
fg1

# %%
fg1.mean()
# Out:
#                   Gross  IMDB_Rating
# Genre
# Action     1.897224e+08     7.949419
# Adventure  1.319017e+08     7.937500
# Animation  1.784326e+08     7.930488
# Biography  9.404952e+07     7.938636
# Comedy     1.010572e+08     7.901290
# Crime      7.899656e+07     8.016822
# Drama      1.225259e+08     7.957439
# Family     2.195553e+08     7.800000
# Fantasy    3.913633e+08     8.000000
# Film-Noir  4.197018e+07     7.966667
# Horror     9.405902e+07     7.909091
# Mystery    1.047014e+08     7.975000
# Thriller   1.755074e+07     7.800000
# Western    1.455538e+07     8.350000

# %%
fg2 = gnr["Genre"]
fg2

# %%
lst3 = []
for gpnm,gpsr in fg2:
    lst3.append(gpsr)
    
a = lst3[0]
a
# Out:
# 2      Action
# 5      Action
# 8      Action
# 10     Action
# 13     Action
#         ...
# 968    Action
# 979    Action
# 982    Action
# 983    Action
# 985    Action
# Name: Genre, Length: 172, dtype: object

# %%
gnr[["Series_Title","Director"]]

# %%
fg5 = gnr[["Metascore","IMDB_Rating","Gross"]]

# %%
fg5.mean()
# Out:
#            Metascore  IMDB_Rating         Gross
# Genre
# Action     73.419580     7.949419  1.897224e+08
# Adventure  78.437500     7.937500  1.319017e+08
# Animation  81.093333     7.930488  1.784326e+08
# Biography  76.240506     7.938636  9.404952e+07
# Comedy     78.720000     7.901290  1.010572e+08
# Crime      77.080460     8.016822  7.899656e+07
# Drama      79.701245     7.957439  1.225259e+08
# Family     79.000000     7.800000  2.195553e+08
# Fantasy          NaN     8.000000  3.913633e+08
# Film-Noir  95.666667     7.966667  4.197018e+07
# Horror     80.000000     7.909091  9.405902e+07
# Mystery    79.125000     7.975000  1.047014e+08
# Thriller   81.000000     7.800000  1.755074e+07
# Western    78.250000     8.350000  1.455538e+07

# %%
gnr.count()
# Out:
#            Series_Title  Released_Year  Runtime  IMDB_Rating  Director  Star1  \
# Genre
# Action              172            172      172          172       172    172
# Adventure            72             72       72           72        72     72
# Animation            82             82       82           82        82     82
# Biography            88             88       88           88        88     88
# Comedy              155            155      155          155       155    155
# Crime               107            107      107          107       107    107
# Drama               289            289      289          289       289    289
# Family                2              2        2            2         2      2
# Fantasy               2              2        2            2         2      2
# Film-Noir             3              3        3            3         3      3
# Horror               11             11       11           11        11     11
# ...

# %%
gnr.count()["Series_Title"]
# Out:
# Genre
# Action       172
# Adventure     72
# Animation     82
# Biography     88
# Comedy       155
# Crime        107
# Drama        289
# Family         2
# Fantasy        2
# Film-Noir      3
# Horror        11
# Mystery       12
# Thriller       1
# Western        4
# Name: Series_Title, dtype: int64

# %%
gnr.max()
# Out:
#                                   Series_Title Released_Year  Runtime  \
# Genre
# Action                                 Yôjinbô          2019      321
# Adventure                           Zombieland            PG      228
# Animation          Ôkami kodomo no Ame to Yuki          2020      137
# Biography                              Zerkalo          2020      209
# Comedy                Zindagi Na Milegi Dobara          2020      188
# Crime                        À bout de souffle          2019      229
# Drama                                Zwartboek          2020      242
# Family     Willy Wonka & the Chocolate Factory          1982      115
# Fantasy                              Nosferatu          1922       94
# Film-Noir                        The Third Man          1949      108
# Horror                               The Thing          2017      122
# Mystery                                Vertigo          2012      138
# ...

# %%
gnr["Gross"].sum()
# Out:
# Genre
# Action       3.263226e+10
# Adventure    9.496922e+09
# Animation    1.463147e+10
# Biography    8.276358e+09
# Comedy       1.566387e+10
# Crime        8.452632e+09
# Drama        3.540997e+10
# Family       4.391106e+08
# Fantasy      7.827267e+08
# Film-Noir    1.259105e+08
# Horror       1.034649e+09
# Mystery      1.256417e+09
# Thriller     1.755074e+07
# Western      5.822151e+07
# Name: Gross, dtype: float64

# %% [markdown]
# ## Find the Top 3 genre according to :-
#
# ### 1)Average IMDB Rating
# ### 2)Maximum MetaScore
# ### 3)Total Gross Income

# %%
gnr

# %%
gnr["IMDB_Rating"].mean().sort_values(ascending=False).head(3)
# Out:
# Genre
# Western    8.350000
# Crime      8.016822
# Fantasy    8.000000
# Name: IMDB_Rating, dtype: float64

# %%
gnr.mean()
# Out:
# C:\Users\pc\AppData\Local\Temp\ipykernel_15348\1217443320.py:1: FutureWarning: The default value of numeric_only in DataFrameGroupBy.mean is deprecated. In a future version, numeric_only will default to False. Either specify numeric_only or select only columns which should be valid for the function.
#   gnr.mean()
#               Runtime  IMDB_Rating    No_of_Votes         Gross  Metascore
# Genre
# Action     129.046512     7.949419  420246.581395  1.897224e+08  73.419580
# Adventure  134.111111     7.937500  313557.819444  1.319017e+08  78.437500
# Animation   99.585366     7.930488  268032.073171  1.784326e+08  81.093333
# Biography  136.022727     7.938636  272805.045455  9.404952e+07  76.240506
# Comedy     112.129032     7.901290  178195.658065  1.010572e+08  78.720000
# Crime      126.392523     8.016822  313398.271028  7.899656e+07  77.080460
# Drama      124.737024     7.957439  212343.612457  1.225259e+08  79.701245
# ...

# %%
gnr["Metascore"].max().sort_values(ascending=False).head(3)
# Out:
# Genre
# Adventure    100.0
# Crime        100.0
# Drama        100.0
# Name: Metascore, dtype: float64

# %%
gnr.max()# to Be seen For NAN
# Out:
#                                   Series_Title Released_Year  Runtime  \
# Genre
# Action                                 Yôjinbô          2019      321
# Adventure                           Zombieland            PG      228
# Animation          Ôkami kodomo no Ame to Yuki          2020      137
# Biography                              Zerkalo          2020      209
# Comedy                Zindagi Na Milegi Dobara          2020      188
# Crime                        À bout de souffle          2019      229
# Drama                                Zwartboek          2020      242
# Family     Willy Wonka & the Chocolate Factory          1982      115
# Fantasy                              Nosferatu          1922       94
# Film-Noir                        The Third Man          1949      108
# Horror                               The Thing          2017      122
# Mystery                                Vertigo          2012      138
# ...

# %%
gnr.get_group("Fantasy")
# Out:
#                      Series_Title Released_Year  Runtime    Genre  \
# 321  Das Cabinet des Dr. Caligari          1920       76  Fantasy
# 568                     Nosferatu          1922       94  Fantasy
#
#      IMDB_Rating      Director          Star1  No_of_Votes        Gross  \
# 321          8.1  Robert Wiene  Werner Krauss        57428  337574718.0
# 568          7.9   F.W. Murnau    Max Schreck        88794  445151978.0
#
#      Metascore
# 321        NaN
# 568        NaN

# %%
gnr["Gross"].sum().sort_values(ascending=False).head(3)
# Out:
# Genre
# Drama     3.540997e+10
# Action    3.263226e+10
# Comedy    1.566387e+10
# Name: Gross, dtype: float64

# %%
gnr.sum()
# Out:
# C:\Users\pc\AppData\Local\Temp\ipykernel_15348\1481780013.py:1: FutureWarning: The default value of numeric_only in DataFrameGroupBy.sum is deprecated. In a future version, numeric_only will default to False. Either specify numeric_only or select only columns which should be valid for the function.
#   gnr.sum()
#            Runtime  IMDB_Rating  No_of_Votes         Gross  Metascore
# Genre
# Action       22196       1367.3     72282412  3.263226e+10    10499.0
# Adventure     9656        571.5     22576163  9.496922e+09     5020.0
# Animation     8166        650.3     21978630  1.463147e+10     6082.0
# Biography    11970        698.6     24006844  8.276358e+09     6023.0
# Comedy       17380       1224.7     27620327  1.566387e+10     9840.0
# Crime        13524        857.8     33533615  8.452632e+09     6706.0
# Drama        36049       2299.7     61367304  3.540997e+10    19208.0
# Family         215         15.6       551221  4.391106e+08      158.0
# ...

# %%
gnr2 = dfmv.groupby(by=["Genre"],as_index=False)
gnr2

# %%
gnr2.count()
# Out:
#         Genre  Series_Title  Released_Year  Runtime  IMDB_Rating  Director  \
# 0      Action           172            172      172          172       172
# 1   Adventure            72             72       72           72        72
# 2   Animation            82             82       82           82        82
# 3   Biography            88             88       88           88        88
# 4      Comedy           155            155      155          155       155
# 5       Crime           107            107      107          107       107
# 6       Drama           289            289      289          289       289
# 7      Family             2              2        2            2         2
# 8     Fantasy             2              2        2            2         2
# 9   Film-Noir             3              3        3            3         3
# 10     Horror            11             11       11           11        11
# ...

# %%
gnr2.mean()
# Out:
# C:\Users\pc\AppData\Local\Temp\ipykernel_15348\2708226904.py:1: FutureWarning: The default value of numeric_only in DataFrameGroupBy.mean is deprecated. In a future version, numeric_only will default to False. Either specify numeric_only or select only columns which should be valid for the function.
#   gnr2.mean()
#         Genre     Runtime  IMDB_Rating    No_of_Votes         Gross  Metascore
# 0      Action  129.046512     7.949419  420246.581395  1.897224e+08  73.419580
# 1   Adventure  134.111111     7.937500  313557.819444  1.319017e+08  78.437500
# 2   Animation   99.585366     7.930488  268032.073171  1.784326e+08  81.093333
# 3   Biography  136.022727     7.938636  272805.045455  9.404952e+07  76.240506
# 4      Comedy  112.129032     7.901290  178195.658065  1.010572e+08  78.720000
# 5       Crime  126.392523     8.016822  313398.271028  7.899656e+07  77.080460
# 6       Drama  124.737024     7.957439  212343.612457  1.225259e+08  79.701245
# ...

# %%
gnr2.groups
# Out:
# {'Action': [2, 5, 8, 10, 13, 14, 16, 29, 30, 31, 39, 42, 44, 55, 57, 59, 60, 63, 68, 72, 106, 109, 129, 130, 134, 140, 142, 144, 152, 155, 160, 161, 166, 168, 171, 172, 177, 181, 194, 201, 202, 216, 217, 223, 224, 236, 241, 262, 275, 294, 308, 320, 325, 326, 331, 337, 339, 340, 343, 345, 348, 351, 353, 356, 357, 362, 368, 369, 375, 376, 390, 410, 431, 436, 473, 477, 479, 482, 488, 493, 496, 502, 507, 511, 532, 535, 540, 543, 564, 569, 570, 573, 577, 582, 583, 602, 605, 608, 615, 623, ...], 'Adventure': [21, 47, 93, 110, 114, 116, 118, 137, 178, 179, 191, 193, 209, 226, 231, 247, 267, 273, 281, 300, 301, 304, 306, 323, 329, 361, 366, 377, 402, 406, 415, 426, 458, 470, 497, 498, 506, 513, 514, 537, 549, 552, 553, 566, 576, 604, 609, 618, 638, 647, 675, 681, 686, 692, 711, 713, 739, 755, 781, 797, 798, 851, 873, 884, 912, 919, 947, 957, 964, 966, 984, 991], 'Animation': [23, 43, 46, 56, 58, 61, 66, 70, 101, 135, 146, 151, 158, 170, 197, 205, 211, 213, 219, 229, 230, 242, 245, 246, 270, 
# ...

# %%
gnr2.indices
# Out:
# {'Action': array([  2,   5,   8,  10,  13,  14,  16,  29,  30,  31,  39,  42,  44,
#          55,  57,  59,  60,  63,  68,  72, 106, 109, 129, 130, 134, 140,
#         142, 144, 152, 155, 160, 161, 166, 168, 171, 172, 177, 181, 194,
#         201, 202, 216, 217, 223, 224, 236, 241, 262, 275, 294, 308, 320,
#         325, 326, 331, 337, 339, 340, 343, 345, 348, 351, 353, 356, 357,
#         362, 368, 369, 375, 376, 390, 410, 431, 436, 473, 477, 479, 482,
#         488, 493, 496, 502, 507, 511, 532, 535, 540, 543, 564, 569, 570,
#         573, 577, 582, 583, 602, 605, 608, 615, 623, 625, 627, 634, 641,
#         642, 645, 648, 655, 659, 663, 666, 674, 677, 678, 685, 696, 702,
#         705, 709, 710, 718, 722, 725, 730, 737, 746, 749, 751, 768, 774,
#         776, 777, 782, 784, 807, 821, 832, 839, 840, 847, 850, 852, 853,
#         854, 856, 861, 865, 887, 888, 889, 893, 896, 898, 900, 901, 908,
#         909, 914, 918, 924, 927, 928, 930, 931, 944, 951, 963, 968, 979,
# ...

# %%
lst2 = []
for gpnm,gpdf in gnr2:
    lst2.append(gpdf)
    
a = lst2[0]
a
# Out:
# C:\Users\pc\AppData\Local\Temp\ipykernel_15348\3455408561.py:2: FutureWarning: In a future version of pandas, a length 1 tuple will be returned when iterating over a groupby with a grouper equal to a list of length 1. Don't supply a list with a single grouper to avoid this warning.
#   for gpnm,gpdf in gnr2:
#                                           Series_Title Released_Year  Runtime  \
# 2                                      The Dark Knight          2008      152
# 5        The Lord of the Rings: The Return of the King          2003      201
# 8                                            Inception          2010      148
# 10   The Lord of the Rings: The Fellowship of the Ring          2001      178
# 13               The Lord of the Rings: The Two Towers          2002      179
# ..                                                 ...           ...      ...
# 968                                       Falling Down          1993      113
# ...

# %%
gnr

# %%
lst[0]
# Out:
#                                           Series_Title Released_Year  Runtime  \
# 2                                      The Dark Knight          2008      152
# 5        The Lord of the Rings: The Return of the King          2003      201
# 8                                            Inception          2010      148
# 10   The Lord of the Rings: The Fellowship of the Ring          2001      178
# 13               The Lord of the Rings: The Two Towers          2002      179
# ..                                                 ...           ...      ...
# 968                                       Falling Down          1993      113
# 979                                      Lethal Weapon          1987      109
# 982                                          Mad Max 2          1981       96
# 983                                       The Warriors          1979       92
# 985                               Escape from Alcatraz          1979      112
#
# ...

# %%
gnr3 = dfmv.groupby(by=["Genre"],sort=False)
gnr3

# %%
gnr3.groups
# Out:
# {'Drama': [0, 9, 11, 17, 20, 24, 32, 34, 36, 40, 45, 50, 53, 62, 65, 67, 73, 74, 76, 80, 82, 84, 85, 88, 89, 90, 91, 92, 94, 97, 98, 99, 100, 104, 105, 121, 122, 124, 126, 138, 141, 143, 148, 149, 150, 154, 156, 167, 174, 175, 182, 184, 185, 188, 190, 195, 196, 199, 200, 203, 206, 210, 225, 227, 234, 237, 244, 248, 249, 253, 254, 258, 259, 260, 264, 265, 268, 269, 272, 274, 278, 279, 280, 283, 285, 286, 289, 291, 292, 293, 295, 296, 297, 302, 303, 307, 310, 312, 314, 315, ...], 'Crime': [1, 3, 4, 6, 22, 25, 27, 28, 33, 37, 41, 71, 77, 79, 86, 87, 103, 108, 111, 113, 123, 125, 133, 136, 162, 163, 164, 165, 180, 186, 187, 189, 198, 222, 232, 239, 255, 257, 287, 288, 299, 305, 335, 363, 364, 380, 384, 397, 437, 438, 441, 442, 444, 450, 451, 465, 474, 480, 485, 487, 505, 512, 519, 520, 523, 527, 546, 556, 560, 584, 597, 603, 607, 611, 621, 639, 653, 664, 669, 676, 695, 708, 723, 762, 763, 767, 775, 791, 795, 802, 811, 823, 827, 833, 885, 895, 921, 922, 926, 938, ...], 'Action': [2, 5, 8,
# ...

# %%
gnr3.get_group("Action")
# Out:
#                                           Series_Title Released_Year  Runtime  \
# 2                                      The Dark Knight          2008      152
# 5        The Lord of the Rings: The Return of the King          2003      201
# 8                                            Inception          2010      148
# 10   The Lord of the Rings: The Fellowship of the Ring          2001      178
# 13               The Lord of the Rings: The Two Towers          2002      179
# ..                                                 ...           ...      ...
# 968                                       Falling Down          1993      113
# 979                                      Lethal Weapon          1987      109
# 982                                          Mad Max 2          1981       96
# 983                                       The Warriors          1979       92
# 985                               Escape from Alcatraz          1979      112
#
# ...

# %%
gnr.cumcount()
# Out:
# 0        0
# 1        0
# 2        0
# 3        1
# 4        2
#       ...
# 995    154
# 996    286
# 997    287
# 998    288
# 999    106
# Length: 1000, dtype: int64

# %%
gnr

# %%
gnr.count()
# Out:
#            Series_Title  Released_Year  Runtime  IMDB_Rating  Director  Star1  \
# Genre
# Action              172            172      172          172       172    172
# Adventure            72             72       72           72        72     72
# Animation            82             82       82           82        82     82
# Biography            88             88       88           88        88     88
# Comedy              155            155      155          155       155    155
# Crime               107            107      107          107       107    107
# Drama               289            289      289          289       289    289
# Family                2              2        2            2         2      2
# Fantasy               2              2        2            2         2      2
# Film-Noir             3              3        3            3         3      3
# Horror               11             11       11           11        11     11
# ...

# %%
gnr.cumcount()
# Out:
# 0        0
# 1        0
# 2        0
# 3        1
# 4        2
#       ...
# 995    154
# 996    286
# 997    287
# 998    288
# 999    106
# Length: 1000, dtype: int64

# %%
dfmv1 = dfmv.copy()

# %%
dfmv1["Rank"] = gnr.cumcount()

# %%
dfmv1
# Out:
#                  Series_Title Released_Year  Runtime   Genre  IMDB_Rating  \
# 0    The Shawshank Redemption          1994      142   Drama          9.3
# 1               The Godfather          1972      175   Crime          9.2
# 2             The Dark Knight          2008      152  Action          9.0
# 3      The Godfather: Part II          1974      202   Crime          9.0
# 4                12 Angry Men          1957       96   Crime          9.0
# ..                        ...           ...      ...     ...          ...
# 995    Breakfast at Tiffany's          1961      115  Comedy          7.6
# 996                     Giant          1956      201   Drama          7.6
# 997     From Here to Eternity          1953      118   Drama          7.6
# 998                  Lifeboat          1944       97   Drama          7.6
# 999              The 39 Steps          1935       86   Crime          7.6
#
#                  Director              Star1  No_of_Votes        Gross  \
# ...

# %%
fggp = dfmv1.groupby(by=["Genre"])

# %%
fggp

# %%
fggp.get_group("Action").iloc[100:150]
# Out:
#                             Series_Title Released_Year  Runtime   Genre  \
# 625                           Apocalypto          2006      139  Action
# 627                             Hot Fuzz          2007      121  Action
# 634                             Serenity          2005      119  Action
# 641         Gongdong gyeongbi guyeok JSA          2000      110  Action
# 642            The Count of Monte Cristo          2002      131  Action
# 645                      Wo hu cang long          2000      120  Action
# 648                  The Boondock Saints          1999      108  Action
# 655                             The Game          1997      129  Action
# 659                            Tombstone          1993      130  Action
# 663                         The Fugitive          1993      130  Action
# 666                     Lat sau san taam          1992      128  Action
# 674                  Dip huet seung hung          1989      111  Action
# ...

# %%
gnr

# %%
pd.set_option('display.max_columns', None)

# %%
gnr.agg(["count","nunique"])
# Out:
#           Series_Title         Released_Year         Runtime          \
#                  count nunique         count nunique   count nunique
# Genre
# Action             172     172           172      61     172      78
# Adventure           72      72            72      49      72      58
# Animation           82      82            82      35      82      41
# Biography           88      88            88      44      88      56
# Comedy             155     155           155      72     155      70
# Crime              107     106           107      56     107      65
# Drama              289     289           289      83     289      95
# Family               2       2             2       2       2       2
# Fantasy              2       2             2       2       2       2
# Film-Noir            3       3             3       3       3       3
# Horror              11      11            11      11      11      10
# ...

# %%
gnr["Metascore"].idxmax()
# Out:
# Genre
# Action        31.0
# Adventure    116.0
# Animation     23.0
# Biography    525.0
# Comedy        52.0
# Crime          1.0
# Drama         50.0
# Family       688.0
# Fantasy        NaN
# Film-Noir    309.0
# Horror        49.0
# Mystery       81.0
# Thriller     700.0
# Western       12.0
# Name: Metascore, dtype: float64

# %%
gnr.get_group("Action").loc[31]
# Out:
# Series_Title     Shichinin no samurai
# Released_Year                    1954
# Runtime                           207
# Genre                          Action
# IMDB_Rating                       8.6
# Director               Akira Kurosawa
# Star1                  Toshirô Mifune
# No_of_Votes                    315744
# Gross                        269061.0
# Metascore                        98.0
# Name: 31, dtype: object

# %%
gnr["Metascore"].max()
# Out:
# Genre
# Action        98.0
# Adventure    100.0
# Animation     96.0
# Biography     97.0
# Comedy        99.0
# Crime        100.0
# Drama        100.0
# Family        91.0
# Fantasy        NaN
# Film-Noir     97.0
# Horror        97.0
# Mystery      100.0
# Thriller      81.0
# Western       90.0
# Name: Metascore, dtype: float64
