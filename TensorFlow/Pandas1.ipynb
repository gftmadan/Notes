# %%
import pandas as pd
import numpy as np
pd.set_option('display.max_rows', 500)
data = {
    'name': ['Utkarsh', 'Vinayak', 'Khushi', 'Mayank', 'Aman', 'Rahul', 'Aayush'],
    'city': ['Lucknow', 'Pune', 'DELHi', 'KolKATa','kanpur', 'MUMBIA', 'banglore'],
    'age':  [25 ,24 ,19 ,17 ,23 ,30 ,22],
    'py-score': [90.4, 89.3, 71.3, 60.9, 58.6, 71.4, 84.6],
    'jv-score': ["85.1","80.7","80.7","55.6","61.6","76.9","88.9"],
    'en-score': ["67","67",65,66,57.9,50.1,65.7]
}

index = range(101, 108)
df = pd.DataFrame(data,index)

# %% [markdown]
# # Reading and Writing csv Files

# %%
df
# Out:
#         name      city  age  py-score jv-score en-score
# 101  Utkarsh   Lucknow   25      90.4     85.1       67
# 102  Vinayak      Pune   24      89.3     80.7       67
# 103   Khushi     DELHi   19      71.3     80.7       65
# 104   Mayank   KolKATa   17      60.9     55.6       66
# 105     Aman    kanpur   23      58.6     61.6     57.9
# 106    Rahul    MUMBIA   30      71.4     76.9     50.1
# 107   Aayush  banglore   22      84.6     88.9     65.7

# %%
df.to_csv()
# Out:
# ',name,city,age,py-score,jv-score,en-score\r\n101,Utkarsh,Lucknow,25,90.4,85.1,67\r\n102,Vinayak,Pune,24,89.3,80.7,67\r\n103,Khushi,DELHi,19,71.3,80.7,65\r\n104,Mayank,KolKATa,17,60.9,55.6,66\r\n105,Aman,kanpur,23,58.6,61.6,57.9\r\n106,Rahul,MUMBIA,30,71.4,76.9,50.1\r\n107,Aayush,banglore,22,84.6,88.9,65.7\r\n'

# %%
df.to_csv(header=False)
# Out:
# '101,Utkarsh,Lucknow,25,90.4,85.1,67\r\n102,Vinayak,Pune,24,89.3,80.7,67\r\n103,Khushi,DELHi,19,71.3,80.7,65\r\n104,Mayank,KolKATa,17,60.9,55.6,66\r\n105,Aman,kanpur,23,58.6,61.6,57.9\r\n106,Rahul,MUMBIA,30,71.4,76.9,50.1\r\n107,Aayush,banglore,22,84.6,88.9,65.7\r\n'

# %%
df.to_csv(header=False,index=False)
# Out:
# 'Utkarsh,Lucknow,25,90.4,85.1,67\r\nVinayak,Pune,24,89.3,80.7,67\r\nKhushi,DELHi,19,71.3,80.7,65\r\nMayank,KolKATa,17,60.9,55.6,66\r\nAman,kanpur,23,58.6,61.6,57.9\r\nRahul,MUMBIA,30,71.4,76.9,50.1\r\nAayush,banglore,22,84.6,88.9,65.7\r\n'

# %%
df.to_csv("abc.csv")

# %%
df.to_csv("abc.csv")

# %%
df.to_csv("abc.csv",header=False,index=False)

# %%
df.to_csv("abc.csv",columns=["name","py-score","jv-score","en-score"])

# %%
df.to_csv("abc.csv",index_label=[101,102,107])

# %%
df.to_csv("abc.csv",index_label="index")

# %%
df.to_csv("abc.svs")

# %%
df.to_csv("abc.csv",columns=["name","py-score","jv-score","en-score","llll"])
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# Cell In[28], line 1
# ----> 1 df.to_csv("abc.csv",columns=["name","py-score","jv-score","en-score","llll"])
#
# File D:\Machine Learning\Sample Project1\env\lib\site-packages\pandas\util\_decorators.py:211, in deprecate_kwarg.<locals>._deprecate_kwarg.<locals>.wrapper(*args, **kwargs)
#     209     else:
#     210         kwargs[new_arg_name] = new_arg_value
# --> 211 return func(*args, **kwargs)
#
# File D:\Machine Learning\Sample Project1\env\lib\site-packages\pandas\core\generic.py:3720, in NDFrame.to_csv(self, path_or_buf, sep, na_rep, float_format, columns, header, index, index_label, mode, encoding, compression, quoting, quotechar, lineterminator, chunksize, date_format, doublequote, escapechar, decimal, errors, storage_options)
#    3709 df = self if isinstance(self, ABCDataFrame) else self.to_frame()
# ...

# %%
df.to_csv("abc.csv",sep=";")

# %%
df.to_csv("abc.csv",sep=";;;")
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[31], line 1
# ----> 1 df.to_csv("abc.csv",sep=";;;")
#
# File D:\Machine Learning\Sample Project1\env\lib\site-packages\pandas\util\_decorators.py:211, in deprecate_kwarg.<locals>._deprecate_kwarg.<locals>.wrapper(*args, **kwargs)
#     209     else:
#     210         kwargs[new_arg_name] = new_arg_value
# --> 211 return func(*args, **kwargs)
#
# File D:\Machine Learning\Sample Project1\env\lib\site-packages\pandas\core\generic.py:3720, in NDFrame.to_csv(self, path_or_buf, sep, na_rep, float_format, columns, header, index, index_label, mode, encoding, compression, quoting, quotechar, lineterminator, chunksize, date_format, doublequote, escapechar, decimal, errors, storage_options)
#    3709 df = self if isinstance(self, ABCDataFrame) else self.to_frame()
#    3711 formatter = DataFrameFormatter(
#    3712     frame=df,
# ...

# %%
data1 = {
    'name': ['Utkarsh', np.NaN, 'Khushi', 'Mayank', 'Aman', 'Rahul', 'Aayush'],
    'city': ['Lucknow', 'Pune', 'DELHi', 'KolKATa','kanpur', np.NaN, 'banglore'],
    'age':  [25 ,24 ,19 ,17 ,23 ,30 ,np.NaN],
    'py-score': [90.4, 89.3, 71.3, 60.9, 58.6, 71.4, 84.6],
    'jv-score': [np.NaN,"80.7","80.7","55.6","61.6","76.9","88.9"],
    'en-score': ["67",np.NaN,65,66,57.9,50.1,65.7]
}

index1 = range(101, 108)
df1 = pd.DataFrame(data1,index1)

# %%
df1
# Out:
#         name      city   age  py-score jv-score en-score
# 101  Utkarsh   Lucknow  25.0      90.4      NaN       67
# 102      NaN      Pune  24.0      89.3     80.7      NaN
# 103   Khushi     DELHi  19.0      71.3     80.7       65
# 104   Mayank   KolKATa  17.0      60.9     55.6       66
# 105     Aman    kanpur  23.0      58.6     61.6     57.9
# 106    Rahul       NaN  30.0      71.4     76.9     50.1
# 107   Aayush  banglore   NaN      84.6     88.9     65.7

# %%
df1.to_csv("nabc.csv")

# %%
df1.to_csv("nabc.csv",na_rep=-999)

# %%
df["qoutes"] = ["I am \"gft\"","I am \"gft1\"","I am \"gft2\"","I am \"gft3\"","I am \"gft4\"","I am \"gft5\"","I am \"gft6\""]

# %%
df
# Out:
#         name      city  age  py-score jv-score en-score       qoutes
# 101  Utkarsh   Lucknow   25      90.4     85.1       67   I am "gft"
# 102  Vinayak      Pune   24      89.3     80.7       67  I am "gft1"
# 103   Khushi     DELHi   19      71.3     80.7       65  I am "gft2"
# 104   Mayank   KolKATa   17      60.9     55.6       66  I am "gft3"
# 105     Aman    kanpur   23      58.6     61.6     57.9  I am "gft4"
# 106    Rahul    MUMBIA   30      71.4     76.9     50.1  I am "gft5"
# 107   Aayush  banglore   22      84.6     88.9     65.7  I am "gft6"

# %%
df.to_csv("abc.csv")

# %%
df2 = pd.read_csv("abc.csv")

# %%
df2
# Out:
#    Unnamed: 0     name      city  age  py-score  jv-score  en-score  \
# 0         101  Utkarsh   Lucknow   25      90.4      85.1      67.0
# 1         102  Vinayak      Pune   24      89.3      80.7      67.0
# 2         103   Khushi     DELHi   19      71.3      80.7      65.0
# 3         104   Mayank   KolKATa   17      60.9      55.6      66.0
# 4         105     Aman    kanpur   23      58.6      61.6      57.9
# 5         106    Rahul    MUMBIA   30      71.4      76.9      50.1
# 6         107   Aayush  banglore   22      84.6      88.9      65.7
#
#         qoutes
# 0   I am "gft"
# 1  I am "gft1"
# 2  I am "gft2"
# 3  I am "gft3"
# 4  I am "gft4"
# 5  I am "gft5"
# 6  I am "gft6"

# %%
df["qoutes"] = ["I am \"g,ft\"","I am \"g,ft1\"","I am \"g,ft2\"","I am \"g,ft3\"","I am \"g,ft4\"","I am \"g,ft5\"","I am \"g,ft6\""]

# %%
df
# Out:
#         name      city  age  py-score jv-score en-score        qoutes
# 101  Utkarsh   Lucknow   25      90.4     85.1       67   I am "g,ft"
# 102  Vinayak      Pune   24      89.3     80.7       67  I am "g,ft1"
# 103   Khushi     DELHi   19      71.3     80.7       65  I am "g,ft2"
# 104   Mayank   KolKATa   17      60.9     55.6       66  I am "g,ft3"
# 105     Aman    kanpur   23      58.6     61.6     57.9  I am "g,ft4"
# 106    Rahul    MUMBIA   30      71.4     76.9     50.1  I am "g,ft5"
# 107   Aayush  banglore   22      84.6     88.9     65.7  I am "g,ft6"

# %%
df.to_csv("abc.csv")

# %%
df4 =pd.read_csv("abc.csv")

# %%
df4
# Out:
#    Unnamed: 0     name      city  age  py-score  jv-score  en-score  \
# 0         101  Utkarsh   Lucknow   25      90.4      85.1      67.0
# 1         102  Vinayak      Pune   24      89.3      80.7      67.0
# 2         103   Khushi     DELHi   19      71.3      80.7      65.0
# 3         104   Mayank   KolKATa   17      60.9      55.6      66.0
# 4         105     Aman    kanpur   23      58.6      61.6      57.9
# 5         106    Rahul    MUMBIA   30      71.4      76.9      50.1
# 6         107   Aayush  banglore   22      84.6      88.9      65.7
#
#          qoutes
# 0   I am "g,ft"
# 1  I am "g,ft1"
# 2  I am "g,ft2"
# 3  I am "g,ft3"
# 4  I am "g,ft4"
# 5  I am "g,ft5"
# 6  I am "g,ft6"

# %%
df.apply(lambda p:p)
# Out:
#         name     city   age  py-score jv-score en-score
# 101  Utkarsh  Lucknow  25.0      90.4      NaN       67
# 102      NaN     Pune  24.0      89.3     80.7      NaN
# 103      NaN    DELHi  19.0      71.3     80.7       65
# 104      NaN  KolKATa  17.0      60.9     55.6       66
# 105     Aman   kanpur  23.0      58.6     61.6     57.9
# 106    Rahul   MUMBIA  30.0      71.4     76.9     50.1
# 107   Aayush      NaN   NaN       NaN     88.9     65.7

# %%
df.apply?

# %%
s1.mean?

# %% [markdown]
# # Group by

# %%
import pandas as pd
import numpy as np

# %%
df1 = pd.read_csv(r"D:\Machine Learning\Sample Project1\Notes Notebooks\Working_Data\matches.csv")

# %%
df1.head()
# Out:
#    id  season       city        date                        team1  \
# 0   1    2017  Hyderabad  2017-04-05          Sunrisers Hyderabad
# 1   2    2017       Pune  2017-04-06               Mumbai Indians
# 2   3    2017     Rajkot  2017-04-07                Gujarat Lions
# 3   4    2017     Indore  2017-04-08       Rising Pune Supergiant
# 4   5    2017  Bangalore  2017-04-08  Royal Challengers Bangalore
#
#                          team2                  toss_winner toss_decision  \
# 0  Royal Challengers Bangalore  Royal Challengers Bangalore         field
# 1       Rising Pune Supergiant       Rising Pune Supergiant         field
# 2        Kolkata Knight Riders        Kolkata Knight Riders         field
# 3              Kings XI Punjab              Kings XI Punjab         field
# 4             Delhi Daredevils  Royal Challengers Bangalore           bat
#
#    result  dl_applied                       winner  win_by_runs  \
# ...

# %%
df1.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 636 entries, 0 to 635
# Data columns (total 18 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   id               636 non-null    int64
#  1   season           636 non-null    int64
#  2   city             629 non-null    object
#  3   date             636 non-null    object
#  4   team1            636 non-null    object
#  5   team2            636 non-null    object
#  6   toss_winner      636 non-null    object
#  7   toss_decision    636 non-null    object
#  8   result           636 non-null    object
#  9   dl_applied       636 non-null    int64
#  10  winner           633 non-null    object
#  11  win_by_runs      636 non-null    int64
#  12  win_by_wickets   636 non-null    int64
#  13  player_of_match  633 non-null    object
#  14  venue            636 non-null    object
#  15  umpire1          635 non-null    object
#  16  umpire2          635 non-null    object
# ...

# %%
seasons = df1.groupby("season")
seasons

# %%
fg1 = seasons.size()
fg1
# Out:
# season
# 2008    58
# 2009    57
# 2010    60
# 2011    73
# 2012    74
# 2013    76
# 2014    60
# 2015    59
# 2016    60
# 2017    59
# dtype: int64

# %%
fg2 = seasons.size().sort_values(ascending=False)
fg2
# Out:
# season
# 2013    76
# 2012    74
# 2011    73
# 2010    60
# 2014    60
# 2016    60
# 2015    59
# 2017    59
# 2008    58
# 2009    57
# dtype: int64

# %%
seasons.groups
# Out:
# {2008: [59, 60, 61, 62, 63, 64, 65, 66, 67, 68, 69, 70, 71, 72, 73, 74, 75, 76, 77, 78, 79, 80, 81, 82, 83, 84, 85, 86, 87, 88, 89, 90, 91, 92, 93, 94, 95, 96, 97, 98, 99, 100, 101, 102, 103, 104, 105, 106, 107, 108, 109, 110, 111, 112, 113, 114, 115, 116], 2009: [117, 118, 119, 120, 121, 122, 123, 124, 125, 126, 127, 128, 129, 130, 131, 132, 133, 134, 135, 136, 137, 138, 139, 140, 141, 142, 143, 144, 145, 146, 147, 148, 149, 150, 151, 152, 153, 154, 155, 156, 157, 158, 159, 160, 161, 162, 163, 164, 165, 166, 167, 168, 169, 170, 171, 172, 173], 2010: [174, 175, 176, 177, 178, 179, 180, 181, 182, 183, 184, 185, 186, 187, 188, 189, 190, 191, 192, 193, 194, 195, 196, 197, 198, 199, 200, 201, 202, 203, 204, 205, 206, 207, 208, 209, 210, 211, 212, 213, 214, 215, 216, 217, 218, 219, 220, 221, 222, 223, 224, 225, 226, 227, 228, 229, 230, 231, 232, 233], 2011: [234, 235, 236, 237, 238, 239, 240, 241, 242, 243, 244, 245, 246, 247, 248, 249, 250, 251, 252, 253, 254, 255, 256, 257, 258, 259, 26
# ...

# %%
df2008 = seasons.get_group(2008)

# %%
winners2008 = df2008.groupby('winner')

# %%
winners2008.get_group('Royal Challengers Bangalore')
# Out:
#       id  season       city        date                        team1  \
# 62    63    2008     Mumbai  2008-04-20               Mumbai Indians
# 79    80    2008  Hyderabad  2008-05-25              Deccan Chargers
# 106  107    2008    Chennai  2008-05-21  Royal Challengers Bangalore
# 110  111    2008  Bangalore  2008-05-03  Royal Challengers Bangalore
#
#                            team2                  toss_winner toss_decision  \
# 62   Royal Challengers Bangalore               Mumbai Indians           bat
# 79   Royal Challengers Bangalore              Deccan Chargers           bat
# 106          Chennai Super Kings  Royal Challengers Bangalore           bat
# 110              Deccan Chargers              Deccan Chargers         field
#
#      result  dl_applied                       winner  win_by_runs  \
# 62   normal           0  Royal Challengers Bangalore            0
# 79   normal           0  Royal Challengers Bangalore            0
# ...

# %%
seasons.sum()
# Out:
# C:\Users\pc\AppData\Local\Temp\ipykernel_10876\3476092050.py:1: FutureWarning: The default value of numeric_only in DataFrameGroupBy.sum is deprecated. In a future version, numeric_only will default to False. Either specify numeric_only or select only columns which should be valid for the function.
#   seasons.sum()
#            id  dl_applied  win_by_runs  win_by_wickets  umpire3
# season
# 2008     5133           2          705             221      0.0
# 2009     8322           3          764             180      0.0
# 2010    12270           0          976             190      0.0
# 2011    19783           3         1098             265      0.0
# 2012    25493           0          960             241      0.0
# 2013    31882           0         1241             227      0.0
# 2014    29250           1          644             225      0.0
# 2015    32273           2          850             148      0.0
# 2016    36390           4          676             244      0.0
# ...

# %%
seasons.min()
# Out:
# C:\Users\pc\AppData\Local\Temp\ipykernel_10876\3103550631.py:1: FutureWarning: Dropping invalid columns in DataFrameGroupBy.min is deprecated. In a future version, a TypeError will be raised. Before calling .min, select only columns which should be valid for the function.
#   seasons.min()
#          id        date                team1                team2  \
# season
# 2008     60  2008-04-18  Chennai Super Kings  Chennai Super Kings
# 2009    118  2009-04-18  Chennai Super Kings  Chennai Super Kings
# 2010    175  2010-03-12  Chennai Super Kings  Chennai Super Kings
# 2011    235  2011-04-08  Chennai Super Kings  Chennai Super Kings
# 2012    308  2012-04-04  Chennai Super Kings  Chennai Super Kings
# 2013    382  2013-04-03  Chennai Super Kings  Chennai Super Kings
# 2014    458  2014-04-16  Chennai Super Kings  Chennai Super Kings
# 2015    518  2015-04-08  Chennai Super Kings  Chennai Super Kings
# 2016    577  2016-04-09     Delhi Daredevils     Delhi Daredevils
# ...

# %%
df1
# Out:
#       id  season       city        date                        team1  \
# 0      1    2017  Hyderabad  2017-04-05          Sunrisers Hyderabad
# 1      2    2017       Pune  2017-04-06               Mumbai Indians
# 2      3    2017     Rajkot  2017-04-07                Gujarat Lions
# 3      4    2017     Indore  2017-04-08       Rising Pune Supergiant
# 4      5    2017  Bangalore  2017-04-08  Royal Challengers Bangalore
# ..   ...     ...        ...         ...                          ...
# 631  632    2016     Raipur  2016-05-22             Delhi Daredevils
# 632  633    2016  Bangalore  2016-05-24                Gujarat Lions
# 633  634    2016      Delhi  2016-05-25          Sunrisers Hyderabad
# 634  635    2016      Delhi  2016-05-27                Gujarat Lions
# 635  636    2016  Bangalore  2016-05-29          Sunrisers Hyderabad
#
#                            team2                  toss_winner toss_decision  \
# ...

# %%
winners = df1.groupby(by=["winner","season"])

# %%
itwin = iter(winners)
group,df = next(itwin)
df
# Out:
#       id  season        city        date                  team1  \
# 60    61    2008  Chandigarh  2008-04-19    Chennai Super Kings
# 66    67    2008     Chennai  2008-04-23    Chennai Super Kings
# 70    71    2008     Chennai  2008-04-26  Kolkata Knight Riders
# 73    74    2008   Bangalore  2008-04-28    Chennai Super Kings
# 86    87    2008       Delhi  2008-05-08       Delhi Daredevils
# 90    91    2008     Chennai  2008-05-10    Chennai Super Kings
# 102  103    2008     Kolkata  2008-05-18  Kolkata Knight Riders
# 113  114    2008   Hyderabad  2008-05-27        Deccan Chargers
# 115  116    2008      Mumbai  2008-05-31        Kings XI Punjab
#
#                            team2            toss_winner toss_decision  result  \
# 60               Kings XI Punjab    Chennai Super Kings           bat  normal
# 66                Mumbai Indians         Mumbai Indians         field  normal
# 70           Chennai Super Kings  Kolkata Knight Riders           bat  normal
# ...

# %%
group,df = next(itwin)
df
# Out:
#       id  season            city        date                        team1  \
# 119  120    2009       Cape Town  2009-04-19              Kings XI Punjab
# 124  125    2009          Durban  2009-04-23             Delhi Daredevils
# 128  129    2009  Port Elizabeth  2009-04-26  Royal Challengers Bangalore
# 135  136    2009       Centurion  2009-04-30              Deccan Chargers
# 145  146    2009          Durban  2009-05-05        Kolkata Knight Riders
# 149  150    2009     East London  2009-05-08               Mumbai Indians
# 153  154    2009    Johannesburg  2009-05-10        Kolkata Knight Riders
# 157  158    2009          Durban  2009-05-13             Delhi Daredevils
# 164  165    2009    Bloemfontein  2009-05-17             Delhi Daredevils
# 169  170    2009       Centurion  2009-05-21               Mumbai Indians
#
#                    team2                  toss_winner toss_decision  result  \
# 119     Delhi Daredevils             Delhi Daredevils         field  normal
# ...

# %%
winners

# %%
seasons

# %%
seasons.get_group(2008)
# Out:
#       id  season        city        date                        team1  \
# 59    60    2008   Bangalore  2008-04-18        Kolkata Knight Riders
# 60    61    2008  Chandigarh  2008-04-19          Chennai Super Kings
# 61    62    2008       Delhi  2008-04-19             Rajasthan Royals
# 62    63    2008      Mumbai  2008-04-20               Mumbai Indians
# 63    64    2008     Kolkata  2008-04-20              Deccan Chargers
# 64    65    2008      Jaipur  2008-04-21              Kings XI Punjab
# 65    66    2008   Hyderabad  2008-04-22              Deccan Chargers
# 66    67    2008     Chennai  2008-04-23          Chennai Super Kings
# 67    68    2008   Hyderabad  2008-04-24              Deccan Chargers
# 68    69    2008  Chandigarh  2008-04-25              Kings XI Punjab
# 69    70    2008   Bangalore  2008-04-26  Royal Challengers Bangalore
# 70    71    2008     Chennai  2008-04-26        Kolkata Knight Riders
# ...

# %%
seasons1 = df1.groupby(by="season",group_keys=False)

# %%
seasons1.groups
# Out:
# {2008: [59, 60, 61, 62, 63, 64, 65, 66, 67, 68, 69, 70, 71, 72, 73, 74, 75, 76, 77, 78, 79, 80, 81, 82, 83, 84, 85, 86, 87, 88, 89, 90, 91, 92, 93, 94, 95, 96, 97, 98, 99, 100, 101, 102, 103, 104, 105, 106, 107, 108, 109, 110, 111, 112, 113, 114, 115, 116], 2009: [117, 118, 119, 120, 121, 122, 123, 124, 125, 126, 127, 128, 129, 130, 131, 132, 133, 134, 135, 136, 137, 138, 139, 140, 141, 142, 143, 144, 145, 146, 147, 148, 149, 150, 151, 152, 153, 154, 155, 156, 157, 158, 159, 160, 161, 162, 163, 164, 165, 166, 167, 168, 169, 170, 171, 172, 173], 2010: [174, 175, 176, 177, 178, 179, 180, 181, 182, 183, 184, 185, 186, 187, 188, 189, 190, 191, 192, 193, 194, 195, 196, 197, 198, 199, 200, 201, 202, 203, 204, 205, 206, 207, 208, 209, 210, 211, 212, 213, 214, 215, 216, 217, 218, 219, 220, 221, 222, 223, 224, 225, 226, 227, 228, 229, 230, 231, 232, 233], 2011: [234, 235, 236, 237, 238, 239, 240, 241, 242, 243, 244, 245, 246, 247, 248, 249, 250, 251, 252, 253, 254, 255, 256, 257, 258, 259, 26
# ...

# %%
seasons.group_keys

# %%
winners = df1.groupby(by=["winner","season"],sort=True)
winners.groups
# Out:
# {('Chennai Super Kings', 2008): [60, 66, 70, 73, 86, 90, 102, 113, 115], ('Chennai Super Kings', 2009): [121, 136, 140, 143, 148, 151, 161, 168], ('Chennai Super Kings', 2010): [181, 184, 201, 205, 210, 221, 227, 231, 233], ('Chennai Super Kings', 2011): [234, 247, 261, 263, 271, 275, 284, 288, 296, 303, 306], ('Chennai Super Kings', 2012): [312, 319, 331, 333, 351, 360, 363, 367, 378, 379], ('Chennai Super Kings', 2013): [390, 395, 403, 405, 409, 413, 417, 421, 424, 434, 445, 453], ('Chennai Super Kings', 2014): [464, 466, 469, 473, 477, 482, 489, 493, 509, 514], ('Chennai Super Kings', 2015): [518, 520, 529, 537, 541, 546, 553, 562, 568, 574], ('Deccan Chargers', 2008): [71, 84], ('Deccan Chargers', 2009): [120, 123, 127, 130, 146, 154, 162, 171, 173], ('Deccan Chargers', 2010): [178, 185, 188, 213, 215, 219, 224, 228], ('Deccan Chargers', 2011): [244, 252, 264, 291, 294, 299], ('Deccan Chargers', 2012): [340, 347, 372, 375], ('Delhi Daredevils', 2008): [61, 65, 75, 78, 97, 103, 10
# ...

# %%
winners = df1.groupby(by=["winner","season"],group_keys=False,sort=False)
winners.groups
# Out:
# {('Chennai Super Kings', 2008): [60, 66, 70, 73, 86, 90, 102, 113, 115], ('Chennai Super Kings', 2009): [121, 136, 140, 143, 148, 151, 161, 168], ('Chennai Super Kings', 2010): [181, 184, 201, 205, 210, 221, 227, 231, 233], ('Chennai Super Kings', 2011): [234, 247, 261, 263, 271, 275, 284, 288, 296, 303, 306], ('Chennai Super Kings', 2012): [312, 319, 331, 333, 351, 360, 363, 367, 378, 379], ('Chennai Super Kings', 2013): [390, 395, 403, 405, 409, 413, 417, 421, 424, 434, 445, 453], ('Chennai Super Kings', 2014): [464, 466, 469, 473, 477, 482, 489, 493, 509, 514], ('Chennai Super Kings', 2015): [518, 520, 529, 537, 541, 546, 553, 562, 568, 574], ('Deccan Chargers', 2008): [71, 84], ('Deccan Chargers', 2009): [120, 123, 127, 130, 146, 154, 162, 171, 173], ('Deccan Chargers', 2010): [178, 185, 188, 213, 215, 219, 224, 228], ('Deccan Chargers', 2011): [244, 252, 264, 291, 294, 299], ('Deccan Chargers', 2012): [340, 347, 372, 375], ('Delhi Daredevils', 2008): [61, 65, 75, 78, 97, 103, 10
# ...
